# %% [markdown]
# # Age Difference Scatterplot Data Processing Notebook
#
# This notebook is for getting the data we need from HCMST2017 for the age difference and marital status scatterplot, which answers the question:
#
# How does age difference influence marital status?

# %%
# The original HMCST2017 file comes as a Stata file, so I exported it from Stata as a CSV
import csv

# %%
data = []
with open('hcmst2017.csv', newline='', encoding='mac_roman') as csvfile:
    reader = csv.DictReader(csvfile)
    i = 0
    for row in reader:
        if i == 0:
            keys = list(row.keys())
            output = ''
            for key in keys:
                output += key + '\n'
            print(output)
        i += 1
        data.append(row)
# Out:
# CaseID
# CASEID_NEW
# qflag
# weight1
# weight1_freqwt
# weight2
# weight1a
# weight1a_freqwt
# weight_combo
# weight_combo_freqwt
# duration
# speed_flag
# consent
# xlgb
# S1
# S2
# S3
# DOV_Branch
# Q3_Refused
# Q4
# Q5
# Q6A
# Q6B
# Q9
# Q10
# Q11
# Q12
# Q14
# Q15A7
# Q16
# Q16_Refused
# Q17A
# Q17B
# Q17C
# Q17D
# Q19
# Q20
# Q21A_Year
# Q21A_Month
# Q21B_Year
# Q21B_Month
# Q21C_Year
# Q21C_Month
# Q21D_Year
# Q21D_Month
# w6_identity
# w6_outness
# w6_outness_timing
# Q23
# Q24_Refused
# Q25
# Q26
# Q27
# Q28
# w6_friend_connect_1
# w6_friend_connect_2
# w6_friend_connect_3
# w6_friend_connect_4
# w6_friend_connect_Refused
# Q32
# Q34
# Q35_Refused
# w6_sex_frequency
# w6_otherdate
# w6_how_many
# w6_how_meet_Refused
# w6_otherdate_app
# w6_how_many_app
# Past_Partner_Q1
# w6_relationship_end_nonmar
# w6_breakup_nonmar
# w6_relationship_end_mar
# w6_who_breakup
# Q5_2
# Q6A_2
# Q9B_2
# Q10_2
# Q11_2
# Q12_2
# Q14_2
# Q15A7_2_1
# Q16_2
# Q16_2_Codes
# Q17B_2
# Q17C_2
# Q17D_2
# Q20_2
# Q21A_2_Year
# Q21A_2_Month
# Q21B_2_Year
# Q21B_2_Month
# Q21C_2_Year
# Q21C_2_Month
# Q21D_2_Year
# Q21D_2_Month
# Q21E_2_Year
# Q21E_2_Month
# Q21F_2_start_range
# Q21F_2_Year
# Q21F_2_Month
# w6_identity_2
# w6_outness_2
# w6_outness_timing_2
# Q23_2
# Q25_2
# Q26_2
# Q27_2
# Q28_2
# w6_friend_connect_2_1
# w6_friend_connect_2_2
# w6_friend_connect_2_3
# w6_friend_connect_2_4
# w6_friend_connect_2_Refused
# Q32_2
# w6_otherdate_2
# w6_how_many_2
# w6_otherdate_app_2
# w6_how_many_app_2
# partyid7
# PERSNET_hom
# ppc10017
# ppc21310
# ppp20071
# ppp20072
# ppage
# ppagecat
# ppagect4
# ppeduc
# ppeducat
# ppethm
# ppgender
# pphhhead
# pphhsize
# pphouse
# ppincimp
# ppmarit
# ppmsacat
# PPREG4
# ppreg9
# pprent
# PPT01
# PPT25
# PPT612
# PPT1317
# PPT18OV
# ppwork
# Race_1
# Race_2
# Race_3
# Race_4
# Race_5
# Race_6
# race1
# race2
# race3
# race4
# race5
# race6
# race7
# race8
# race9
# race10
# race11
# race12
# race13
# race14
# race15
# w6_took_the_survey
# w6_prior_identity_lgb
# w6_same_sex_couple
# w6_same_sex_couple_gender
# w6_q4
# w6_q5
# w6_q6a
# w6_q6b
# w6_q9
# w6_q10
# w6_q11
# w6_q12
# w6_q14
# w6_q15a1_truncated
# w6_q15a4_truncated
# w6_q15a7
# w6_q16
# w6_q17
# w6_attraction
# w6_q19
# w6_q20
# w6_q21a_year
# w6_q21a_month
# w6_q21a_month_flag
# w6_q21b_year
# w6_q21b_month
# w6_q21b_month_flag
# w6_q21c_year
# w6_q21c_month
# w6_q21c_month_flag
# w6_q21d_year
# w6_q21d_month
# w6_q21e_year
# w6_q21e_month
# w6_q21f_year
# w6_q21f_month
# w6_identity_all
# w6_outness_all
# w6_outness_timing_all
# w6_q23
# w6_q24_length
# w6_q25
# w6_q26
# w6_q27
# w6_q28
# w6_friend_connect_1_all
# w6_friend_connect_2_all
# w6_friend_connect_3_all
# w6_friend_connect_4_all
# w6_q32
# w6_q34
# w6_otherdate_all
# w6_how_many_all
# w6_otherdate_app_all
# w6_how_many_app_all
# w6_number_people_met
# w6_otherdate_dichotomous
# w6_married
# relate_duration_at_w6_years
# w6_number_people_met_app
# weight_combo_v2
# partnership_status
# female
# year_fraction_met
# year_fraction_relstart
# age_when_met
# time_from_met_to_rel
# year_fraction_first_cohab
# time_from_rel_to_cohab
# hcm2017q24_R_cowork
# hcm2017q24_R_friend
# hcm2017q24_R_family
# hcm2017q24_R_sig_other
# hcm2017q24_R_neighbor
# hcm2017q24_P_cowork
# hcm2017q24_P_friend
# hcm2017q24_P_family
# hcm2017q24_P_sig_other
# hcm2017q24_P_neighbor
# hcm2017q24_btwn_I_cowork
# hcm2017q24_btwn_I_friend
# hcm2017q24_btwn_I_family
# hcm2017q24_btwn_I_sig_other
# hcm2017q24_btwn_I_neighbor
# hcm2017q24_school
# hcm2017q24_college
# hcm2017q24_mil
# hcm2017q24_church
# hcm2017q24_vol_org
# hcm2017q24_customer
# hcm2017q24_bar_restaurant
# hcm2017q24_party
# hcm2017q24_internet_other
# hcm2017q24_internet_dating
# hcm2017q24_internet_soc_network
# hcm2017q24_internet_game
# hcm2017q24_internet_chat
# hcm2017q24_internet_org
# hcm2017q24_public
# hcm2017q24_blind_date
# hcm2017q24_vacation
# hcm2017q24_single_serve_nonint
# hcm2017q24_business_trip
# hcm2017q24_work_neighbors
# hcm2017q24_met_online
# hcm2017_q24_length
# hcm2017q24_summary_all_codes
# w6_relationship_quality
# hcm2017q24_met_through_family
# hcm2017q24_met_through_friend
# hcm2017q24_met_through_as_nghbrs
# hcm2017q24_met_as_through_cowork
# w6_subject_race
# interracial_5cat
# partner_mother_yrsed
# subject_mother_yrsed
# partner_yrsed
# subject_yrsed

# %%
print(data[2000]["DOV_Branch"])
# Out:
# 2

# %%
participant_age = set()
for datum in data:
    participant_age.add(datum["ppage"])
print(participant_age)
# Out:
# {'32', '45', '63', '67', '34', '23', '74', '76', '42', '21', '61', '79', '37', '59', '19', '68', '75', '44', '89', '78', '57', '35', '83', '40', '36', '27', '81', '33', '50', '70', '29', '86', '55', '30', '25', '26', '46', '56', '47', '41', '80', '85', '72', '71', '39', '91', '77', '66', '92', '54', '48', '73', '69', '65', '90', '22', '28', '58', '38', '87', '88', '49', '64', '31', '60', '51', '62', '52', '93', '53', '84', '24', '43', '82', '20', '18'}

# %%
partner_age = set()
for datum in data:
    partner_age.add(datum["Q9"])
print(partner_age)
# Out:
# {'', '67', '63', '17', '10', '61', '37', '75', '81', '40', '95', '50', '26', '41', '80', '47', '71', '77', '66', '54', '73', '69', '16', '90', '22', '28', '60', '45', '76', '21', '59', '19', '57', '36', '27', '70', '55', '85', '72', '87', '52', '53', '20', '68', '44', '89', '78', '83', '33', '86', '25', '56', '48', '58', '38', '49', '64', '51', '31', 'Refused', '32', '79', '34', '23', '74', '42', '35', '29', '30', '46', '39', '91', '65', '62', '14', '84', '24', '43', '82', '18'}

# %%
marital_status = set()
for datum in data:
    marital_status.add(datum["ppmarit"])
print(marital_status)
# Out:
# {'Living with partner', 'Married', 'Never married', 'Separated', 'Widowed', 'Divorced'}

# %%
export_data = []
for person in data:
    if not person["Q9"] or person["Q9"] == 'Refused':
        continue
    export_data.append(
        { "participant_age": int(person["ppage"]), 
         "partner_age": int(person["Q9"]),
        "marital_status": person["ppmarit"]}
    )

# %%
export_data
# Out:
# [{'participant_age': 55, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 47, 'partner_age': 45, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 33, 'partner_age': 43, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 35, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 42, 'marital_status': 'Married'},
#  {'participant_age': 34,
#   'partner_age': 37,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 46, 'partner_age': 40, 'marital_status': 'Married'},
#  {'participant_age': 49, 'partner_age': 40, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 72, 'marital_status': 'Married'},
#  {'participant_age': 41, 'partner_age': 40, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 55, 'marital_status': 'Widowed'},
#  {'participant_age': 32, 'partner_age': 35, 'marital_status': 'Married'},
#  {'participant_age': 45, 'partner_age': 45, 'marital_status': 'Married'},
#  {'participant_age': 23, 'partner_age': 25, 'marital_status': 'Never married'},
#  {'participant_age': 38, 'partner_age': 43, 'marital_status': 'Never married'},
#  {'participant_age': 23, 'partner_age': 22, 'marital_status': 'Divorced'},
#  {'participant_age': 26, 'partner_age': 26, 'marital_status': 'Married'},
#  {'participant_age': 70, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 47, 'partner_age': 39, 'marital_status': 'Married'},
#  {'participant_age': 33, 'partner_age': 32, 'marital_status': 'Married'},
#  {'participant_age': 20, 'partner_age': 24, 'marital_status': 'Never married'},
#  {'participant_age': 58, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 50, 'partner_age': 53, 'marital_status': 'Divorced'},
#  {'participant_age': 48, 'partner_age': 58, 'marital_status': 'Separated'},
#  {'participant_age': 22, 'partner_age': 28, 'marital_status': 'Never married'},
#  {'participant_age': 62, 'partner_age': 48, 'marital_status': 'Married'},
#  {'participant_age': 32,
#   'partner_age': 32,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 53, 'partner_age': 55, 'marital_status': 'Divorced'},
#  {'participant_age': 36, 'partner_age': 34, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 62, 'partner_age': 64, 'marital_status': 'Married'},
#  {'participant_age': 33, 'partner_age': 23, 'marital_status': 'Married'},
#  {'participant_age': 41, 'partner_age': 40, 'marital_status': 'Married'},
#  {'participant_age': 60,
#   'partner_age': 58,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 58, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 54, 'marital_status': 'Married'},
#  {'participant_age': 70, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 60, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 30, 'partner_age': 32, 'marital_status': 'Never married'},
#  {'participant_age': 26, 'partner_age': 28, 'marital_status': 'Married'},
#  {'participant_age': 39,
#   'partner_age': 36,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 31,
#   'partner_age': 29,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 47,
#   'partner_age': 41,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 76, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 75, 'partner_age': 74, 'marital_status': 'Married'},
#  {'participant_age': 45, 'partner_age': 45, 'marital_status': 'Married'},
#  {'participant_age': 74, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 58, 'marital_status': 'Widowed'},
#  {'participant_age': 38,
#   'partner_age': 37,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 69, 'partner_age': 72, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 36, 'partner_age': 34, 'marital_status': 'Married'},
#  {'participant_age': 19, 'partner_age': 21, 'marital_status': 'Never married'},
#  {'participant_age': 42, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 25, 'partner_age': 30, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 71, 'marital_status': 'Married'},
#  {'participant_age': 74, 'partner_age': 73, 'marital_status': 'Married'},
#  {'participant_age': 24,
#   'partner_age': 24,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 48, 'partner_age': 49, 'marital_status': 'Married'},
#  {'participant_age': 68, 'partner_age': 71, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 65, 'marital_status': 'Never married'},
#  {'participant_age': 35, 'partner_age': 37, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 27,
#   'partner_age': 29,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 64, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 43, 'partner_age': 45, 'marital_status': 'Married'},
#  {'participant_age': 44,
#   'partner_age': 43,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 71, 'partner_age': 71, 'marital_status': 'Divorced'},
#  {'participant_age': 40, 'partner_age': 50, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 71, 'marital_status': 'Married'},
#  {'participant_age': 67, 'partner_age': 68, 'marital_status': 'Married'},
#  {'participant_age': 36, 'partner_age': 36, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 75, 'partner_age': 72, 'marital_status': 'Married'},
#  {'participant_age': 43, 'partner_age': 46, 'marital_status': 'Married'},
#  {'participant_age': 43, 'partner_age': 42, 'marital_status': 'Married'},
#  {'participant_age': 42, 'partner_age': 43, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 46, 'marital_status': 'Separated'},
#  {'participant_age': 29, 'partner_age': 26, 'marital_status': 'Never married'},
#  {'participant_age': 46,
#   'partner_age': 37,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 68, 'partner_age': 69, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 27, 'marital_status': 'Divorced'},
#  {'participant_age': 68, 'partner_age': 68, 'marital_status': 'Married'},
#  {'participant_age': 82, 'partner_age': 80, 'marital_status': 'Married'},
#  {'participant_age': 82, 'partner_age': 72, 'marital_status': 'Married'},
#  {'participant_age': 46, 'partner_age': 45, 'marital_status': 'Married'},
#  {'participant_age': 43, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 28, 'partner_age': 29, 'marital_status': 'Married'},
#  {'participant_age': 75, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 62, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 64, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 48, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 64, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 70, 'marital_status': 'Married'},
#  {'participant_age': 76, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 24, 'partner_age': 25, 'marital_status': 'Never married'},
#  {'participant_age': 47, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 26,
#   'partner_age': 30,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 34, 'partner_age': 34, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 68, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 48, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 42, 'marital_status': 'Divorced'},
#  {'participant_age': 58, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 30, 'partner_age': 48, 'marital_status': 'Divorced'},
#  {'participant_age': 67, 'partner_age': 37, 'marital_status': 'Divorced'},
#  {'participant_age': 28, 'partner_age': 30, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 64, 'marital_status': 'Married'},
#  {'participant_age': 40, 'partner_age': 50, 'marital_status': 'Married'},
#  {'participant_age': 53, 'partner_age': 50, 'marital_status': 'Never married'},
#  {'participant_age': 49, 'partner_age': 48, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 30, 'partner_age': 30, 'marital_status': 'Married'},
#  {'participant_age': 28, 'partner_age': 27, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 42, 'partner_age': 50, 'marital_status': 'Married'},
#  {'participant_age': 80, 'partner_age': 68, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 39, 'marital_status': 'Married'},
#  {'participant_age': 30, 'partner_age': 39, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 67, 'marital_status': 'Widowed'},
#  {'participant_age': 73, 'partner_age': 50, 'marital_status': 'Married'},
#  {'participant_age': 36, 'partner_age': 34, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 68, 'partner_age': 69, 'marital_status': 'Widowed'},
#  {'participant_age': 56, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 23, 'partner_age': 24, 'marital_status': 'Never married'},
#  {'participant_age': 64, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 30, 'partner_age': 36, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 76, 'partner_age': 76, 'marital_status': 'Married'},
#  {'participant_age': 23, 'partner_age': 35, 'marital_status': 'Married'},
#  {'participant_age': 76, 'partner_age': 77, 'marital_status': 'Married'},
#  {'participant_age': 89, 'partner_age': 50, 'marital_status': 'Widowed'},
#  {'participant_age': 57, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 62, 'partner_age': 22, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 32, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 69, 'marital_status': 'Married'},
#  {'participant_age': 28, 'partner_age': 28, 'marital_status': 'Never married'},
#  {'participant_age': 68, 'partner_age': 68, 'marital_status': 'Married'},
#  {'participant_age': 84, 'partner_age': 66, 'marital_status': 'Widowed'},
#  {'participant_age': 24, 'partner_age': 24, 'marital_status': 'Never married'},
#  {'participant_age': 42, 'partner_age': 35, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 52,
#   'partner_age': 51,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 46, 'partner_age': 43, 'marital_status': 'Married'},
#  {'participant_age': 26, 'partner_age': 32, 'marital_status': 'Never married'},
#  {'participant_age': 43, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 46, 'partner_age': 54, 'marital_status': 'Married'},
#  {'participant_age': 52,
#   'partner_age': 68,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 65, 'partner_age': 69, 'marital_status': 'Never married'},
#  {'participant_age': 55, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 73, 'partner_age': 80, 'marital_status': 'Married'},
#  {'participant_age': 27, 'partner_age': 28, 'marital_status': 'Widowed'},
#  {'participant_age': 45, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 84, 'partner_age': 83, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 43, 'marital_status': 'Divorced'},
#  {'participant_age': 35, 'partner_age': 30, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 44, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 73, 'partner_age': 70, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 31,
#   'partner_age': 30,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 54, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 79, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 73, 'partner_age': 55, 'marital_status': 'Widowed'},
#  {'participant_age': 70,
#   'partner_age': 25,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 49, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 46, 'partner_age': 46, 'marital_status': 'Married'},
#  {'participant_age': 28, 'partner_age': 23, 'marital_status': 'Married'},
#  {'participant_age': 28, 'partner_age': 27, 'marital_status': 'Married'},
#  {'participant_age': 93, 'partner_age': 95, 'marital_status': 'Married'},
#  {'participant_age': 46, 'partner_age': 48, 'marital_status': 'Never married'},
#  {'participant_age': 26, 'partner_age': 28, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 77, 'partner_age': 70, 'marital_status': 'Married'},
#  {'participant_age': 42, 'partner_age': 42, 'marital_status': 'Married'},
#  {'participant_age': 78, 'partner_age': 70, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 42, 'partner_age': 40, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 70, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 46, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 50,
#   'partner_age': 46,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 40, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 73, 'partner_age': 72, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 77, 'partner_age': 68, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 42, 'partner_age': 43, 'marital_status': 'Married'},
#  {'participant_age': 39, 'partner_age': 40, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 53, 'partner_age': 50, 'marital_status': 'Never married'},
#  {'participant_age': 68, 'partner_age': 70, 'marital_status': 'Married'},
#  {'participant_age': 49, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 64, 'marital_status': 'Married'},
#  {'participant_age': 60, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 39, 'marital_status': 'Married'},
#  {'participant_age': 82, 'partner_age': 75, 'marital_status': 'Widowed'},
#  {'participant_age': 74, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 45, 'partner_age': 36, 'marital_status': 'Married'},
#  {'participant_age': 45, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 53, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 70, 'partner_age': 69, 'marital_status': 'Married'},
#  {'participant_age': 62, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 81, 'partner_age': 83, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 53, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 63, 'marital_status': 'Widowed'},
#  {'participant_age': 70, 'partner_age': 73, 'marital_status': 'Married'},
#  {'participant_age': 40, 'partner_age': 35, 'marital_status': 'Never married'},
#  {'participant_age': 64, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 26,
#   'partner_age': 26,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 72, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 31,
#   'partner_age': 31,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 35, 'partner_age': 34, 'marital_status': 'Married'},
#  {'participant_age': 20, 'partner_age': 21, 'marital_status': 'Never married'},
#  {'participant_age': 53, 'partner_age': 49, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 36, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 59, 'marital_status': 'Divorced'},
#  {'participant_age': 28, 'partner_age': 38, 'marital_status': 'Never married'},
#  {'participant_age': 70, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 26, 'partner_age': 31, 'marital_status': 'Married'},
#  {'participant_age': 50, 'partner_age': 63, 'marital_status': 'Divorced'},
#  {'participant_age': 30, 'partner_age': 28, 'marital_status': 'Never married'},
#  {'participant_age': 73, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 62, 'marital_status': 'Divorced'},
#  {'participant_age': 54, 'partner_age': 48, 'marital_status': 'Divorced'},
#  {'participant_age': 92, 'partner_age': 85, 'marital_status': 'Widowed'},
#  {'participant_age': 51, 'partner_age': 50, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 60, 'marital_status': 'Never married'},
#  {'participant_age': 42, 'partner_age': 44, 'marital_status': 'Married'},
#  {'participant_age': 43, 'partner_age': 43, 'marital_status': 'Married'},
#  {'participant_age': 23, 'partner_age': 27, 'marital_status': 'Never married'},
#  {'participant_age': 57, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 75, 'partner_age': 73, 'marital_status': 'Married'},
#  {'participant_age': 71, 'partner_age': 69, 'marital_status': 'Married'},
#  {'participant_age': 29, 'partner_age': 29, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 50, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 51, 'marital_status': 'Married'},
#  {'participant_age': 35, 'partner_age': 36, 'marital_status': 'Married'},
#  {'participant_age': 46, 'partner_age': 39, 'marital_status': 'Divorced'},
#  {'participant_age': 50, 'partner_age': 45, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 43, 'partner_age': 36, 'marital_status': 'Married'},
#  {'participant_age': 85, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 83, 'partner_age': 78, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 68, 'marital_status': 'Married'},
#  {'participant_age': 80, 'partner_age': 74, 'marital_status': 'Married'},
#  {'participant_age': 47, 'partner_age': 37, 'marital_status': 'Separated'},
#  {'participant_age': 37, 'partner_age': 45, 'marital_status': 'Married'},
#  {'participant_age': 51, 'partner_age': 46, 'marital_status': 'Married'},
#  {'participant_age': 32, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 51, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 43, 'partner_age': 43, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 48, 'marital_status': 'Never married'},
#  {'participant_age': 70, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 55,
#   'partner_age': 54,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 51, 'partner_age': 46, 'marital_status': 'Divorced'},
#  {'participant_age': 72, 'partner_age': 76, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 71, 'partner_age': 61, 'marital_status': 'Widowed'},
#  {'participant_age': 28, 'partner_age': 29, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 32, 'partner_age': 32, 'marital_status': 'Married'},
#  {'participant_age': 51, 'partner_age': 27, 'marital_status': 'Married'},
#  {'participant_age': 68, 'partner_age': 55, 'marital_status': 'Never married'},
#  {'participant_age': 52, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 27, 'partner_age': 20, 'marital_status': 'Never married'},
#  {'participant_age': 76, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 28, 'partner_age': 34, 'marital_status': 'Never married'},
#  {'participant_age': 73, 'partner_age': 73, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 84, 'partner_age': 83, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 42, 'partner_age': 41, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 60,
#   'partner_age': 56,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 25,
#   'partner_age': 27,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 26, 'partner_age': 30, 'marital_status': 'Married'},
#  {'participant_age': 23, 'partner_age': 25, 'marital_status': 'Never married'},
#  {'participant_age': 68, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 68, 'partner_age': 69, 'marital_status': 'Married'},
#  {'participant_age': 53, 'partner_age': 54, 'marital_status': 'Married'},
#  {'participant_age': 30, 'partner_age': 26, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 20, 'marital_status': 'Never married'},
#  {'participant_age': 39, 'partner_age': 39, 'marital_status': 'Never married'},
#  {'participant_age': 28, 'partner_age': 33, 'marital_status': 'Married'},
#  {'participant_age': 75, 'partner_age': 70, 'marital_status': 'Married'},
#  {'participant_age': 31,
#   'partner_age': 32,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 63, 'partner_age': 74, 'marital_status': 'Married'},
#  {'participant_age': 39, 'partner_age': 37, 'marital_status': 'Married'},
#  {'participant_age': 25, 'partner_age': 26, 'marital_status': 'Separated'},
#  {'participant_age': 52, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 29, 'partner_age': 31, 'marital_status': 'Married'},
#  {'participant_age': 68, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 77, 'partner_age': 74, 'marital_status': 'Widowed'},
#  {'participant_age': 42, 'partner_age': 24, 'marital_status': 'Never married'},
#  {'participant_age': 24, 'partner_age': 24, 'marital_status': 'Never married'},
#  {'participant_age': 33,
#   'partner_age': 30,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 40, 'partner_age': 35, 'marital_status': 'Married'},
#  {'participant_age': 29, 'partner_age': 27, 'marital_status': 'Never married'},
#  {'participant_age': 56, 'partner_age': 54, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 22,
#   'partner_age': 23,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 38, 'partner_age': 37, 'marital_status': 'Never married'},
#  {'participant_age': 30, 'partner_age': 39, 'marital_status': 'Divorced'},
#  {'participant_age': 32,
#   'partner_age': 30,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 42, 'partner_age': 43, 'marital_status': 'Divorced'},
#  {'participant_age': 60,
#   'partner_age': 49,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 54, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 38,
#   'partner_age': 43,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 33, 'partner_age': 35, 'marital_status': 'Married'},
#  {'participant_age': 73, 'partner_age': 79, 'marital_status': 'Married'},
#  {'participant_age': 43, 'partner_age': 44, 'marital_status': 'Married'},
#  {'participant_age': 34,
#   'partner_age': 33,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 42,
#   'partner_age': 41,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 28,
#   'partner_age': 28,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 58, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 65, 'marital_status': 'Divorced'},
#  {'participant_age': 35, 'partner_age': 36, 'marital_status': 'Married'},
#  {'participant_age': 28, 'partner_age': 27, 'marital_status': 'Married'},
#  {'participant_age': 60, 'partner_age': 50, 'marital_status': 'Divorced'},
#  {'participant_age': 32, 'partner_age': 32, 'marital_status': 'Married'},
#  {'participant_age': 71, 'partner_age': 70, 'marital_status': 'Married'},
#  {'participant_age': 29,
#   'partner_age': 28,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 56, 'partner_age': 51, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 65, 'marital_status': 'Divorced'},
#  {'participant_age': 40, 'partner_age': 46, 'marital_status': 'Married'},
#  {'participant_age': 21, 'partner_age': 21, 'marital_status': 'Never married'},
#  {'participant_age': 25,
#   'partner_age': 25,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 64, 'partner_age': 64, 'marital_status': 'Married'},
#  {'participant_age': 34, 'partner_age': 40, 'marital_status': 'Married'},
#  {'participant_age': 40,
#   'partner_age': 46,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 31, 'partner_age': 32, 'marital_status': 'Married'},
#  {'participant_age': 33, 'partner_age': 37, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 64, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 37, 'marital_status': 'Married'},
#  {'participant_age': 62, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 40, 'partner_age': 36, 'marital_status': 'Married'},
#  {'participant_age': 58,
#   'partner_age': 43,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 36,
#   'partner_age': 54,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 74, 'partner_age': 76, 'marital_status': 'Married'},
#  {'participant_age': 25,
#   'partner_age': 25,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 60, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 54, 'marital_status': 'Married'},
#  {'participant_age': 25, 'partner_age': 26, 'marital_status': 'Never married'},
#  {'participant_age': 62, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 47, 'partner_age': 47, 'marital_status': 'Divorced'},
#  {'participant_age': 27, 'partner_age': 27, 'marital_status': 'Never married'},
#  {'participant_age': 55, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 49, 'partner_age': 46, 'marital_status': 'Married'},
#  {'participant_age': 29, 'partner_age': 29, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 34, 'partner_age': 35, 'marital_status': 'Married'},
#  {'participant_age': 60, 'partner_age': 74, 'marital_status': 'Married'},
#  {'participant_age': 27, 'partner_age': 36, 'marital_status': 'Never married'},
#  {'participant_age': 47,
#   'partner_age': 56,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 42, 'partner_age': 43, 'marital_status': 'Married'},
#  {'participant_age': 73, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 44, 'partner_age': 51, 'marital_status': 'Never married'},
#  {'participant_age': 36, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 65, 'marital_status': 'Separated'},
#  {'participant_age': 52, 'partner_age': 45, 'marital_status': 'Divorced'},
#  {'participant_age': 47, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 70, 'partner_age': 72, 'marital_status': 'Married'},
#  {'participant_age': 45,
#   'partner_age': 44,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 44, 'partner_age': 44, 'marital_status': 'Divorced'},
#  {'participant_age': 34, 'partner_age': 29, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 33, 'marital_status': 'Married'},
#  {'participant_age': 30, 'partner_age': 62, 'marital_status': 'Never married'},
#  {'participant_age': 27,
#   'partner_age': 42,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 56, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 64, 'marital_status': 'Married'},
#  {'participant_age': 50, 'partner_age': 46, 'marital_status': 'Married'},
#  {'participant_age': 26,
#   'partner_age': 26,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 30, 'partner_age': 35, 'marital_status': 'Never married'},
#  {'participant_age': 76, 'partner_age': 64, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 50, 'partner_age': 46, 'marital_status': 'Married'},
#  {'participant_age': 52, 'partner_age': 41, 'marital_status': 'Married'},
#  {'participant_age': 30, 'partner_age': 32, 'marital_status': 'Married'},
#  {'participant_age': 48,
#   'partner_age': 55,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 54, 'partner_age': 49, 'marital_status': 'Married'},
#  {'participant_age': 28,
#   'partner_age': 28,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 61, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 53,
#   'partner_age': 56,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 28,
#   'partner_age': 28,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 27, 'partner_age': 25, 'marital_status': 'Never married'},
#  {'participant_age': 38, 'partner_age': 41, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 49, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 26, 'partner_age': 26, 'marital_status': 'Married'},
#  {'participant_age': 74, 'partner_age': 78, 'marital_status': 'Widowed'},
#  {'participant_age': 58, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 76, 'partner_age': 77, 'marital_status': 'Widowed'},
#  {'participant_age': 50, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 27,
#   'partner_age': 27,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 46, 'partner_age': 47, 'marital_status': 'Divorced'},
#  {'participant_age': 63, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 33, 'partner_age': 39, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 34, 'partner_age': 34, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 39, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 70, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 40, 'marital_status': 'Married'},
#  {'participant_age': 74, 'partner_age': 79, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 29, 'partner_age': 29, 'marital_status': 'Never married'},
#  {'participant_age': 54, 'partner_age': 51, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 28, 'marital_status': 'Never married'},
#  {'participant_age': 26,
#   'partner_age': 27,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 70, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 54, 'marital_status': 'Married'},
#  {'participant_age': 46, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 82, 'partner_age': 87, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 31, 'partner_age': 31, 'marital_status': 'Married'},
#  {'participant_age': 27, 'partner_age': 27, 'marital_status': 'Never married'},
#  {'participant_age': 35, 'partner_age': 31, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 48, 'partner_age': 38, 'marital_status': 'Separated'},
#  {'participant_age': 60, 'partner_age': 61, 'marital_status': 'Divorced'},
#  {'participant_age': 79, 'partner_age': 78, 'marital_status': 'Married'},
#  {'participant_age': 34, 'partner_age': 34, 'marital_status': 'Married'},
#  {'participant_age': 44, 'partner_age': 48, 'marital_status': 'Married'},
#  {'participant_age': 53, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 70, 'partner_age': 62, 'marital_status': 'Widowed'},
#  {'participant_age': 65, 'partner_age': 73, 'marital_status': 'Married'},
#  {'participant_age': 71, 'partner_age': 68, 'marital_status': 'Married'},
#  {'participant_age': 24,
#   'partner_age': 28,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 42, 'partner_age': 40, 'marital_status': 'Married'},
#  {'participant_age': 75, 'partner_age': 86, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 76, 'partner_age': 70, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 43, 'marital_status': 'Divorced'},
#  {'participant_age': 33, 'partner_age': 30, 'marital_status': 'Married'},
#  {'participant_age': 41, 'partner_age': 54, 'marital_status': 'Married'},
#  {'participant_age': 53, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 29,
#   'partner_age': 30,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 65, 'partner_age': 71, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 78, 'partner_age': 79, 'marital_status': 'Married'},
#  {'participant_age': 53,
#   'partner_age': 57,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 60, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 34, 'partner_age': 34, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 49, 'marital_status': 'Married'},
#  {'participant_age': 45, 'partner_age': 42, 'marital_status': 'Married'},
#  {'participant_age': 29, 'partner_age': 28, 'marital_status': 'Never married'},
#  {'participant_age': 75, 'partner_age': 77, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 37, 'marital_status': 'Separated'},
#  {'participant_age': 67, 'partner_age': 66, 'marital_status': 'Divorced'},
#  {'participant_age': 33, 'partner_age': 33, 'marital_status': 'Divorced'},
#  {'participant_age': 26, 'partner_age': 26, 'marital_status': 'Married'},
#  {'participant_age': 53, 'partner_age': 55, 'marital_status': 'Never married'},
#  {'participant_age': 74, 'partner_age': 81, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 58, 'marital_status': 'Divorced'},
#  {'participant_age': 50, 'partner_age': 40, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 52, 'partner_age': 50, 'marital_status': 'Married'},
#  {'participant_age': 54,
#   'partner_age': 62,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 60, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 71, 'partner_age': 76, 'marital_status': 'Married'},
#  {'participant_age': 18, 'partner_age': 18, 'marital_status': 'Never married'},
#  {'participant_age': 60, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 18, 'partner_age': 18, 'marital_status': 'Never married'},
#  {'participant_age': 63, 'partner_age': 56, 'marital_status': 'Divorced'},
#  {'participant_age': 55, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 43, 'partner_age': 43, 'marital_status': 'Married'},
#  {'participant_age': 67, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 54, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 46, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 54, 'marital_status': 'Divorced'},
#  {'participant_age': 61, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 34, 'partner_age': 33, 'marital_status': 'Married'},
#  {'participant_age': 40, 'partner_age': 42, 'marital_status': 'Married'},
#  {'participant_age': 41, 'partner_age': 46, 'marital_status': 'Divorced'},
#  {'participant_age': 47, 'partner_age': 50, 'marital_status': 'Separated'},
#  {'participant_age': 49, 'partner_age': 51, 'marital_status': 'Married'},
#  {'participant_age': 33,
#   'partner_age': 35,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 47, 'partner_age': 49, 'marital_status': 'Married'},
#  {'participant_age': 44,
#   'partner_age': 43,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 70, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 19, 'partner_age': 20, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 51, 'marital_status': 'Married'},
#  {'participant_age': 40, 'partner_age': 49, 'marital_status': 'Never married'},
#  {'participant_age': 69, 'partner_age': 82, 'marital_status': 'Married'},
#  {'participant_age': 73,
#   'partner_age': 64,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 27,
#   'partner_age': 27,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 41, 'partner_age': 48, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 71, 'marital_status': 'Married'},
#  {'participant_age': 41, 'partner_age': 41, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 45, 'marital_status': 'Separated'},
#  {'participant_age': 68, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 36,
#   'partner_age': 35,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 22, 'partner_age': 27, 'marital_status': 'Married'},
#  {'participant_age': 29, 'partner_age': 24, 'marital_status': 'Never married'},
#  {'participant_age': 72, 'partner_age': 74, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 50, 'marital_status': 'Married'},
#  {'participant_age': 43, 'partner_age': 43, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 40, 'partner_age': 35, 'marital_status': 'Married'},
#  {'participant_age': 23, 'partner_age': 25, 'marital_status': 'Married'},
#  {'participant_age': 33, 'partner_age': 42, 'marital_status': 'Married'},
#  {'participant_age': 62, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 26, 'partner_age': 26, 'marital_status': 'Married'},
#  {'participant_age': 26,
#   'partner_age': 25,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 78, 'partner_age': 77, 'marital_status': 'Married'},
#  {'participant_age': 44, 'partner_age': 35, 'marital_status': 'Married'},
#  {'participant_age': 44, 'partner_age': 48, 'marital_status': 'Married'},
#  {'participant_age': 62, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 79, 'partner_age': 84, 'marital_status': 'Married'},
#  {'participant_age': 68, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 60, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 49, 'partner_age': 36, 'marital_status': 'Married'},
#  {'participant_age': 27, 'partner_age': 29, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 67, 'partner_age': 64, 'marital_status': 'Married'},
#  {'participant_age': 35, 'partner_age': 34, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 26, 'partner_age': 33, 'marital_status': 'Married'},
#  {'participant_age': 41, 'partner_age': 40, 'marital_status': 'Married'},
#  {'participant_age': 45, 'partner_age': 37, 'marital_status': 'Separated'},
#  {'participant_age': 55, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 62, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 74, 'partner_age': 79, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 64,
#   'partner_age': 65,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 30, 'partner_age': 26, 'marital_status': 'Never married'},
#  {'participant_age': 71, 'partner_age': 71, 'marital_status': 'Married'},
#  {'participant_age': 71, 'partner_age': 69, 'marital_status': 'Married'},
#  {'participant_age': 28, 'partner_age': 32, 'marital_status': 'Married'},
#  {'participant_age': 45, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 68, 'marital_status': 'Divorced'},
#  {'participant_age': 40, 'partner_age': 37, 'marital_status': 'Married'},
#  {'participant_age': 53, 'partner_age': 54, 'marital_status': 'Never married'},
#  {'participant_age': 62, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 49, 'marital_status': 'Separated'},
#  {'participant_age': 56, 'partner_age': 58, 'marital_status': 'Divorced'},
#  {'participant_age': 65, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 60, 'partner_age': 56, 'marital_status': 'Widowed'},
#  {'participant_age': 52, 'partner_age': 50, 'marital_status': 'Married'},
#  {'participant_age': 40, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 47,
#   'partner_age': 66,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 74, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 35, 'partner_age': 37, 'marital_status': 'Married'},
#  {'participant_age': 24, 'partner_age': 23, 'marital_status': 'Never married'},
#  {'participant_age': 52, 'partner_age': 46, 'marital_status': 'Divorced'},
#  {'participant_age': 62, 'partner_age': 60, 'marital_status': 'Divorced'},
#  {'participant_age': 72, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 75, 'partner_age': 74, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 67, 'partner_age': 72, 'marital_status': 'Married'},
#  {'participant_age': 30, 'partner_age': 21, 'marital_status': 'Never married'},
#  {'participant_age': 63, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 44, 'partner_age': 44, 'marital_status': 'Married'},
#  {'participant_age': 75, 'partner_age': 76, 'marital_status': 'Married'},
#  {'participant_age': 39, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 27,
#   'partner_age': 28,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 57, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 37, 'marital_status': 'Married'},
#  {'participant_age': 32, 'partner_age': 34, 'marital_status': 'Married'},
#  {'participant_age': 50, 'partner_age': 50, 'marital_status': 'Divorced'},
#  {'participant_age': 26, 'partner_age': 24, 'marital_status': 'Separated'},
#  {'participant_age': 25, 'partner_age': 30, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 68, 'partner_age': 68, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 21, 'marital_status': 'Never married'},
#  {'participant_age': 60, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 52, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 35, 'partner_age': 33, 'marital_status': 'Married'},
#  {'participant_age': 42,
#   'partner_age': 38,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 41, 'partner_age': 42, 'marital_status': 'Never married'},
#  {'participant_age': 39, 'partner_age': 31, 'marital_status': 'Married'},
#  {'participant_age': 49, 'partner_age': 67, 'marital_status': 'Divorced'},
#  {'participant_age': 29, 'partner_age': 26, 'marital_status': 'Married'},
#  {'participant_age': 53, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 48, 'partner_age': 44, 'marital_status': 'Married'},
#  {'participant_age': 45, 'partner_age': 43, 'marital_status': 'Married'},
#  {'participant_age': 23,
#   'partner_age': 23,
# ...
#  {'participant_age': 29,
#   'partner_age': 23,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 26,
#   'partner_age': 27,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 19, 'partner_age': 19, 'marital_status': 'Never married'},
#  {'participant_age': 75, 'partner_age': 70, 'marital_status': 'Married'},
#  {'participant_age': 34, 'partner_age': 30, 'marital_status': 'Married'},
#  {'participant_age': 27,
#   'partner_age': 25,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 58, 'partner_age': 74, 'marital_status': 'Divorced'},
#  {'participant_age': 68, 'partner_age': 32, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 51, 'marital_status': 'Widowed'},
#  {'participant_age': 84, 'partner_age': 86, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 64, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 35, 'marital_status': 'Married'},
#  {'participant_age': 81, 'partner_age': 78, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 26,
#   'partner_age': 27,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 70, 'partner_age': 74, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 27, 'partner_age': 19, 'marital_status': 'Never married'},
#  {'participant_age': 28,
#   'partner_age': 29,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 52, 'partner_age': 54, 'marital_status': 'Married'},
#  {'participant_age': 40, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 45, 'marital_status': 'Married'},
#  {'participant_age': 73, 'partner_age': 73, 'marital_status': 'Widowed'},
#  {'participant_age': 58, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 58, 'marital_status': 'Never married'},
#  {'participant_age': 74, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 53, 'marital_status': 'Divorced'},
#  {'participant_age': 65, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 47, 'partner_age': 48, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 44, 'marital_status': 'Divorced'},
#  {'participant_age': 70, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 85, 'partner_age': 85, 'marital_status': 'Married'},
#  {'participant_age': 19, 'partner_age': 20, 'marital_status': 'Never married'},
#  {'participant_age': 49, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 20, 'partner_age': 21, 'marital_status': 'Never married'},
#  {'participant_age': 33, 'partner_age': 32, 'marital_status': 'Married'},
#  {'participant_age': 25, 'partner_age': 23, 'marital_status': 'Never married'},
#  {'participant_age': 58, 'partner_age': 60, 'marital_status': 'Divorced'},
#  {'participant_age': 46, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 54, 'marital_status': 'Never married'},
#  {'participant_age': 37,
#   'partner_age': 35,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 37, 'partner_age': 44, 'marital_status': 'Married'},
#  {'participant_age': 26,
#   'partner_age': 24,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 76, 'partner_age': 77, 'marital_status': 'Married'},
#  {'participant_age': 30,
#   'partner_age': 31,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 69, 'partner_age': 69, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 71, 'marital_status': 'Widowed'},
#  {'participant_age': 59, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 21, 'partner_age': 52, 'marital_status': 'Never married'},
#  {'participant_age': 37, 'partner_age': 40, 'marital_status': 'Separated'},
#  {'participant_age': 67,
#   'partner_age': 54,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 32, 'partner_age': 41, 'marital_status': 'Separated'},
#  {'participant_age': 53, 'partner_age': 49, 'marital_status': 'Separated'},
#  {'participant_age': 22, 'partner_age': 21, 'marital_status': 'Never married'},
#  {'participant_age': 54, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 26, 'partner_age': 27, 'marital_status': 'Married'},
#  {'participant_age': 35, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 35, 'partner_age': 37, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 23, 'partner_age': 28, 'marital_status': 'Never married'},
#  {'participant_age': 70, 'partner_age': 69, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 68, 'partner_age': 69, 'marital_status': 'Married'},
#  {'participant_age': 35, 'partner_age': 39, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 58, 'marital_status': 'Divorced'},
#  {'participant_age': 55, 'partner_age': 54, 'marital_status': 'Married'},
#  {'participant_age': 71, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 46, 'partner_age': 45, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 52, 'marital_status': 'Divorced'},
#  {'participant_age': 32, 'partner_age': 37, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 46, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 77, 'marital_status': 'Married'},
#  {'participant_age': 60, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 49, 'marital_status': 'Married'},
#  {'participant_age': 36,
#   'partner_age': 34,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 75, 'partner_age': 71, 'marital_status': 'Married'},
#  {'participant_age': 27,
#   'partner_age': 26,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 63, 'partner_age': 58, 'marital_status': 'Married'},
#  {'participant_age': 76, 'partner_age': 75, 'marital_status': 'Married'},
#  {'participant_age': 28,
#   'partner_age': 31,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 81, 'partner_age': 73, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 66, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 85, 'partner_age': 84, 'marital_status': 'Married'},
#  {'participant_age': 51, 'partner_age': 51, 'marital_status': 'Divorced'},
#  {'participant_age': 35,
#   'partner_age': 32,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 26,
#   'partner_age': 35,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 60, 'partner_age': 45, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 47, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 73, 'partner_age': 73, 'marital_status': 'Married'},
#  {'participant_age': 62, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 36, 'partner_age': 37, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 68, 'marital_status': 'Married'},
#  {'participant_age': 73, 'partner_age': 71, 'marital_status': 'Married'},
#  {'participant_age': 53, 'partner_age': 52, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 41, 'partner_age': 35, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 21, 'partner_age': 22, 'marital_status': 'Never married'},
#  {'participant_age': 56, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 65, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 28, 'partner_age': 29, 'marital_status': 'Never married'},
#  {'participant_age': 49, 'partner_age': 46, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 30, 'partner_age': 28, 'marital_status': 'Never married'},
#  {'participant_age': 67, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 62, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 67, 'partner_age': 57, 'marital_status': 'Married'},
#  {'participant_age': 27, 'partner_age': 26, 'marital_status': 'Married'},
#  {'participant_age': 46, 'partner_age': 37, 'marital_status': 'Divorced'},
#  {'participant_age': 64, 'partner_age': 67, 'marital_status': 'Married'},
#  {'participant_age': 27, 'partner_age': 28, 'marital_status': 'Never married'},
#  {'participant_age': 51, 'partner_age': 47, 'marital_status': 'Never married'},
#  {'participant_age': 48, 'partner_age': 49, 'marital_status': 'Married'},
#  {'participant_age': 48, 'partner_age': 50, 'marital_status': 'Married'},
#  {'participant_age': 45, 'partner_age': 45, 'marital_status': 'Married'},
#  {'participant_age': 35, 'partner_age': 32, 'marital_status': 'Never married'},
#  {'participant_age': 42, 'partner_age': 43, 'marital_status': 'Married'},
#  {'participant_age': 56, 'partner_age': 37, 'marital_status': 'Divorced'},
#  {'participant_age': 55, 'partner_age': 61, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 45, 'marital_status': 'Separated'},
#  {'participant_age': 60, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 40, 'partner_age': 51, 'marital_status': 'Married'},
#  {'participant_age': 68, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 51,
#   'partner_age': 42,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 20, 'partner_age': 29, 'marital_status': 'Never married'},
#  {'participant_age': 70, 'partner_age': 73, 'marital_status': 'Married'},
#  {'participant_age': 50, 'partner_age': 46, 'marital_status': 'Married'},
#  {'participant_age': 71, 'partner_age': 72, 'marital_status': 'Married'},
#  {'participant_age': 22,
#   'partner_age': 21,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 39, 'partner_age': 31, 'marital_status': 'Married'},
#  {'participant_age': 57, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 59, 'partner_age': 60, 'marital_status': 'Married'},
#  {'participant_age': 58, 'partner_age': 57, 'marital_status': 'Divorced'},
#  {'participant_age': 62, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 70, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 62, 'partner_age': 66, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 59, 'marital_status': 'Married'},
#  {'participant_age': 25,
#   'partner_age': 25,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 83, 'partner_age': 84, 'marital_status': 'Married'},
#  {'participant_age': 51, 'partner_age': 43, 'marital_status': 'Never married'},
#  {'participant_age': 55, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 61, 'partner_age': 56, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 53, 'marital_status': 'Married'},
#  {'participant_age': 43, 'partner_age': 44, 'marital_status': 'Married'},
#  {'participant_age': 48, 'partner_age': 37, 'marital_status': 'Separated'},
#  {'participant_age': 51, 'partner_age': 49, 'marital_status': 'Married'},
#  {'participant_age': 31, 'partner_age': 32, 'marital_status': 'Married'},
#  {'participant_age': 70, 'partner_age': 76, 'marital_status': 'Married'},
#  {'participant_age': 63, 'partner_age': 63, 'marital_status': 'Divorced'},
#  {'participant_age': 61, 'partner_age': 45, 'marital_status': 'Never married'},
#  {'participant_age': 40, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 26, 'partner_age': 24, 'marital_status': 'Married'},
#  {'participant_age': 41, 'partner_age': 51, 'marital_status': 'Married'},
#  {'participant_age': 30, 'partner_age': 30, 'marital_status': 'Never married'},
#  {'participant_age': 44, 'partner_age': 41, 'marital_status': 'Married'},
#  {'participant_age': 27, 'partner_age': 28, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 71, 'marital_status': 'Married'},
#  {'participant_age': 72, 'partner_age': 71, 'marital_status': 'Married'},
#  {'participant_age': 71, 'partner_age': 69, 'marital_status': 'Married'},
#  {'participant_age': 68, 'partner_age': 69, 'marital_status': 'Married'},
#  {'participant_age': 54, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 62,
#   'partner_age': 61,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 64, 'partner_age': 65, 'marital_status': 'Married'},
#  {'participant_age': 85, 'partner_age': 84, 'marital_status': 'Married'},
#  {'participant_age': 64, 'partner_age': 63, 'marital_status': 'Married'},
#  {'participant_age': 38, 'partner_age': 37, 'marital_status': 'Never married'},
#  {'participant_age': 27, 'partner_age': 28, 'marital_status': 'Never married'},
#  {'participant_age': 41, 'partner_age': 43, 'marital_status': 'Separated'},
#  {'participant_age': 34, 'partner_age': 37, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 55, 'partner_age': 55, 'marital_status': 'Married'},
#  {'participant_age': 31, 'partner_age': 33, 'marital_status': 'Married'},
#  {'participant_age': 39, 'partner_age': 36, 'marital_status': 'Married'},
#  {'participant_age': 32,
#   'partner_age': 27,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 26, 'partner_age': 22, 'marital_status': 'Never married'},
#  {'participant_age': 32, 'partner_age': 28, 'marital_status': 'Divorced'},
#  {'participant_age': 30, 'partner_age': 29, 'marital_status': 'Married'},
#  {'participant_age': 43,
#   'partner_age': 38,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 43, 'partner_age': 44, 'marital_status': 'Married'},
#  {'participant_age': 68, 'partner_age': 68, 'marital_status': 'Divorced'},
#  {'participant_age': 81, 'partner_age': 79, 'marital_status': 'Separated'},
#  {'participant_age': 52, 'partner_age': 47, 'marital_status': 'Married'},
#  {'participant_age': 43,
#   'partner_age': 47,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 62, 'partner_age': 71, 'marital_status': 'Married'},
#  {'participant_age': 29,
#   'partner_age': 34,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 32,
#   'partner_age': 36,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 56, 'partner_age': 50, 'marital_status': 'Married'},
#  {'participant_age': 46,
#   'partner_age': 30,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 39,
#   'partner_age': 35,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 61, 'partner_age': 62, 'marital_status': 'Married'},
#  {'participant_age': 37, 'partner_age': 38, 'marital_status': 'Married'},
#  {'participant_age': 69, 'partner_age': 70, 'marital_status': 'Married'},
#  {'participant_age': 29, 'partner_age': 30, 'marital_status': 'Married'},
#  {'participant_age': 54,
#   'partner_age': 57,
#   'marital_status': 'Living with partner'},
#  {'participant_age': 59, 'partner_age': 54, 'marital_status': 'Married'},
#  {'participant_age': 50, 'partner_age': 57, 'marital_status': 'Widowed'},
#  {'participant_age': 48,
#   'partner_age': 47,
#   'marital_status': 'Living with partner'},
#  ...]

# %%
import json

# %%
export_json = json.dumps(export_data)

# %%
export_json
# Out:
# '[{"participant_age": 55, "partner_age": 52, "marital_status": "Married"}, {"participant_age": 47, "partner_age": 45, "marital_status": "Married"}, {"participant_age": 59, "partner_age": 59, "marital_status": "Married"}, {"participant_age": 59, "partner_age": 60, "marital_status": "Married"}, {"participant_age": 66, "partner_age": 67, "marital_status": "Married"}, {"participant_age": 65, "partner_age": 65, "marital_status": "Married"}, {"participant_age": 33, "partner_age": 43, "marital_status": "Married"}, {"participant_age": 37, "partner_age": 35, "marital_status": "Married"}, {"participant_age": 38, "partner_age": 42, "marital_status": "Married"}, {"participant_age": 34, "partner_age": 37, "marital_status": "Living with partner"}, {"participant_age": 46, "partner_age": 40, "marital_status": "Married"}, {"participant_age": 49, "partner_age": 40, "marital_status": "Married"}, {"participant_age": 66, "partner_age": 72, "marital_status": "Married"}, {"participant_age": 41, "partner_age": 40, "marital_status": "Married"}, {"participant_age": 64, "partner_age": 55, "marital_status": "Widowed"}, {"participant_age": 32, "partner_age": 35, "marital_status": "Married"}, {"participant_age": 45, "partner_age": 45, "marital_status": "Married"}, {"participant_age": 23, "partner_age": 25, "marital_status": "Never married"}, {"participant_age": 38, "partner_age": 43, "marital_status": "Never married"}, {"participant_age": 23, "partner_age": 22, "marital_status": "Divorced"}, {"participant_age": 26, "partner_age": 26, "marital_status": "Married"}, {"participant_age": 70, "partner_age": 75, "marital_status": "Married"}, {"participant_age": 47, "partner_age": 39, "marital_status": "Married"}, {"participant_age": 33, "partner_age": 32, "marital_status": "Married"}, {"participant_age": 20, "partner_age": 24, "marital_status": "Never married"}, {"participant_age": 58, "partner_age": 62, "marital_status": "Married"}, {"participant_age": 50, "partner_age": 53, "marital_status": "Divorced"}, {"participant_age": 48, "partner_age": 58, "marital_status": "Separated"}, {"participant_age": 22, "partner_age": 28, "marital_status": "Never married"}, {"participant_age": 62, "partner_age": 48, "marital_status": "Married"}, {"participant_age": 32, "partner_age": 32, "marital_status": "Living with partner"}, {"participant_age": 53, "partner_age": 55, "marital_status": "Divorced"}, {"participant_age": 36, "partner_age": 34, "marital_status": "Married"}, {"participant_age": 38, "partner_age": 52, "marital_status": "Married"}, {"participant_age": 62, "partner_age": 64, "marital_status": "Married"}, {"participant_age": 33, "partner_age": 23, "marital_status": "Married"}, {"participant_age": 41, "partner_age": 40, "marital_status": "Married"}, {"participant_age": 60, "partner_age": 58, "marital_status": "Living with partner"}, {"participant_age": 58, "partner_age": 55, "marital_status": "Married"}, {"participant_age": 55, "partner_age": 54, "marital_status": "Married"}, {"participant_age": 70, "partner_age": 67, "marital_status": "Married"}, {"participant_age": 54, "partner_age": 53, "marital_status": "Married"}, {"participant_age": 60, "partner_age": 62, "marital_status": "Married"}, {"participant_age": 30, "partner_age": 32, "marital_status": "Never married"}, {"participant_age": 26, "partner_age": 28, "marital_status": "Married"}, {"participant_age": 39, "partner_age": 36, "marital_status": "Living with partner"}, {"participant_age": 31, "partner_age": 29, "marital_status": "Living with partner"}, {"participant_age": 47, "partner_age": 41, "marital_status": "Living with partner"}, {"participant_age": 76, "partner_age": 67, "marital_status": "Married"}, {"participant_age": 63, "partner_age": 63, "marital_status": "Married"}, {"participant_age": 55, "partner_age": 59, "marital_status": "Married"}, {"participant_age": 75, "partner_age": 74, "marital_status": "Married"}, {"participant_age": 45, "partner_age": 45, "marital_status": "Married"}, {"participant_age": 74 ...
